# %%
# %sql
select * from samples.bakehouse.media_customer_reviews;
# Out:
#   Cell In[1], line 2
#     select * from samples.bakehouse.media_customer_reviews;
#              ^
# SyntaxError: invalid syntax

# %%
# %sql
select 1
